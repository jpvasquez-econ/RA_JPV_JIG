# %% [markdown]
# # Rapid Fuzz
# ## Controlling ORBIS by entity and municipality and DENUE by entity and municipality

# %% [markdown]
# # General information
# This notebook mainly executes the following for the firm names in `denue_final` and `orbis_final`:
#
# - Filtering the desired geographical zones in both data sets.
# - Extracting the company names.
# - Training the algorithm.
# - Extracting the results.
# - Labeling the results.
# - Exporting them to a Comma Separated Values file.
#
# After this, we've got the possible name matches in `denue_final` for each company in `orbis_final`.

# %% [markdown]
# # Input files
# 1. **orbis_final:** `'/scratch/public/jpvasquez/MNCs_informality/Intermediate_data/output/orbis_final.csv'` This file contains a data set where each row represents a firm with one of their names associated, also, entity, municipality and ORBIS's BVDID number.
# 2. **denue_final_alternative:** `'/scratch/public/jpvasquez/MNCs_informality/Intermediate_data/output/denue_final_alternative.csv'` This file contains a dataset where each row represents a firm with one of their names associated, also, the number of workers in that firm, entity, municipality and DENUE's key.

# %%
orbis_final_file = '/scratch/public/jpvasquez/MNCs_informality/Intermediate_data/output/orbis_final.csv'
denue_final_alternative_file = '/scratch/public/jpvasquez/MNCs_informality/Intermediate_data/output/denue_final_alternative.csv'

# %% [markdown]
# # Output files
# 1. **output_file_prefix:** `'/scratch/public/jpvasquez/MNCs_informality/Final_data/output/both_entity_municipality/denue_alternative/rapidfuzz/matches_rapidfuzz_both_'` These files contain the possible matches of each municipality.
# 2. **final_output:** `'/scratch/public/jpvasquez/MNCs_informality/Final_data/output/2-2-2-1-matches_tf_idf_both_entity_municipality_alternative.csv'` This file is a concatenation of all the `output_file_prefix` files.

# %%
output_file_prefix = '/scratch/public/jpvasquez/MNCs_informality/Final_data/output/both_entity_municipality/denue_alternative/rapidfuzz/matches_rapidfuzz_both_'
final_output = '/scratch/public/jpvasquez/MNCs_informality/Final_data/output/2-2-2-1-matches_rapidfuzz_both_entity_municipality_alternative.csv'

# %% [markdown]
# # Packages
# These are the needed packages to run this code. In case, the machine you're running this in doesn't have any of these packages, run this code:
#
# `!pip install package_name`
#
# - **Pandas** is the package which handles importing, wrangling, cleaning and doing everything with the data.
# - **Numpy** is needed in order to declare missing values.
# - **Glob** gets all the files from a directory with a prefix.
# - **Sklearn** is a package for machile learning, we'll use the module for Natural Language Processing.
# - **Scipy** is used for scientific computing, in our case, `csr_matrix` is a dependency of `awesome_cossim_topn`.
# - **Sparse_dot_topn** performs sparse matrix multiplication followed by top-n multiplication result selection.

# %%
import pandas as pd
import numpy as np
import glob
import dask as dd
from rapidfuzz import fuzz
import dask.dataframe as dd
# Out:
# /usr/local/linux/anaconda3.7/lib/python3.7/site-packages/dask/dataframe/utils.py:13: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Importing the data

# %%
orbis_final = pd.read_csv(orbis_final_file)
denue_final = pd.read_csv(denue_final_alternative_file)

# %% [markdown]
# # Declaring options
# For customizability's sake, we'll group all the variables, options and arguments we could wish to change in the future. We'll make it in one cell, but feel free to split it into how many cells you want.

# %%
# base_df
base_data = orbis_final
category1 = 'entidad' # control 1 for groupby
category2 = 'municipio' # control 2 for groupby
# matching_df
matching_data = denue_final
base_names_variable = 'companyname' # control 1 for groupby
matching_names_variable = 'firm' # control 2 for groupby
# extracting the results
## top results
top_results_lower_bound = 0.95 # lowest score accepted for top quality matches
## uncertain results
uncertain_results_lower_bound = 0.9 # lowest score accepted for uncertain quality matches
uncertain_results_upper_bound = 0.95 # highest score accepted for uncertain quality matches
n_uncertain_results = 5 # top n results for uncertain matches
##################################
### don't change anything below###
##################################
categories = [category1, category2]

# %% [markdown]
# # Selecting the inner set of categories in `denue_final` and `orbis_final`
# - Get the unique categories tuples.
# - Keep the observations in each dataset that match the unique categories.

# %%
coincident_categories = (base_data[categories]
                         .drop_duplicates() # select the unique controlling variable combinations in base_data
                         .merge(matching_data[categories]
                                .drop_duplicates(), # select the unique controlling variable combinations in base_data
                                how = 'inner', left_on = categories, 
                                right_on = categories)) # merge 'inner' to get the pairs in both data sets

base_data = (base_data.merge(coincident_categories, how = 'inner', # keep the observations that
                             left_on = categories, right_on = categories)) #  match the inner unique categories
matching_data = matching_data.merge(coincident_categories, how = 'inner', # keep the observations that
                                    left_on = categories, right_on = categories) #  match the inner unique categories

# %% [markdown]
# # Matching algorithm
# Since this is a loop, we can't divide the algorithm in separate cells, so, we'll comment it with #.
# The main sections are:
#
# - Filter the datasets with their corresponding categories.
# - Get the company names.
# - Train the algorithm.
# - Extract the results.
#     - Top results.
#     - Uncertain results.
# - Save the matches.

# %%
i = 0
for base_group, base_df in base_data.groupby(by = categories): 
    i += 1
    print(f'Matching {base_group}, combination {i} of out 389')
    #########################
    ###Filter the datasets###
    #########################
    base_df = (base_df.copy()
               .dropna(subset = [base_names_variable]) # drop observations without variable name (firm name)
               .drop_duplicates(ignore_index=True)) # drop possible duplicates
    matching_df = (matching_data[(matching_data[category1] == base_group[0]) # filter the matching dataset
                                 & (matching_data[category2] == base_group[1])] # to match a category tuple
                   .copy() 
                   .dropna(subset = [matching_names_variable]) # drop observations without variable name (firm name)
                   .drop_duplicates(ignore_index=True)) # drop possible duplicates
    ###################################
    ###Converting to Dask Dataframes###
    ###################################
    base_df = dd.from_pandas(base_df, chunksize = 50)
    matching_df = dd.from_pandas(matching_df, chunksize = 500)
    ########################################
    ###All combinations of the dataframes###
    ########################################
    base_df = base_df.assign(key = 0) # set key to match on
    matching_df = matching_df.assign(key = 0)# set key to match on
    matches = dd.merge(base_df, matching_df, suffixes=('_x', '_y'), on = "key", 
                       how = 'outer', shuffle = 'tasks').compute() # tasks: to use distributed computations on all nodes
    ############################
    ###Extracting the results###
    ############################
    matches['score'] = matches.apply(lambda x: 
                                     fuzz.token_sort_ratio(x[base_names_variable], 
                                                                     x[matching_names_variable])/100, 
                                     axis = 1) # apply algorithm
    ############
    #Top results
    ############
    certain_matches = matches[matches['score'] > top_results_lower_bound].copy()
    certain_matches['accuracy'] = 'top' # tag them as top results
    
    ##################
    #Uncertain results
    ##################
    uncertain_matches = (matches[(matches['score'] < uncertain_results_upper_bound) 
                                 & (matches['score'] > uncertain_results_lower_bound)] # select the matches below upper bound
                         .copy() 
                         .sort_values(['score'], ascending = False) # sort values descending
                         .groupby('bvdidnumber').head(n_uncertain_results)) # group by bvdidnumber, then get the n best matches
    uncertain_matches['accuracy'] = 'uncertain' # tag them as uncertain results
    
    ########################
    ###Saving the matches###
    ########################
    
    matches = certain_matches.append(uncertain_matches, ignore_index = True) # append certain with uncertain matches
    file_name = output_file_prefix + base_group[0] + '_' + base_group[1] + '_alternative' + '.csv' # create file name
    matches.drop_duplicates(ignore_index = True).to_csv(file_name, index = False) # remove duplicates and save
# Out:
# Matching ('aguascalientes', 'aguascalientes'), combination 1 of out 389
# Matching ('aguascalientes', 'el_llano'), combination 2 of out 389
# Matching ('aguascalientes', 'jesus_maria'), combination 3 of out 389
# Matching ('aguascalientes', 'rincon_de_romos'), combination 4 of out 389
# Matching ('aguascalientes', 'san_francisco_de_los_romo'), combination 5 of out 389
# Matching ('baja_california', 'ensenada'), combination 6 of out 389
# Matching ('baja_california', 'mexicali'), combination 7 of out 389
# Matching ('baja_california', 'playas_de_rosarito'), combination 8 of out 389
# Matching ('baja_california', 'tecate'), combination 9 of out 389
# Matching ('baja_california', 'tijuana'), combination 10 of out 389
# Matching ('baja_california_sur', 'la_paz'), combination 11 of out 389
# Matching ('baja_california_sur', 'los_cabos'), combination 12 of out 389
# Matching ('baja_california_sur', 'mulege'), combination 13 of out 389
# Matching ('campeche', 'campeche'), combination 14 of out 389
# Matching ('campeche', 'carmen'), combination 15 of out 389
# Matching ('campeche', 'champoton'), combination 16 of out 389
# Matching ('campeche', 'hopelchen'), combination 17 of out 389
# Matching ('campeche', 'palizada'), combination 18 of out 389
# Matching ('chiapas', 'arriaga'), combination 19 of out 389
# Matching ('chiapas', 'palenque'), combination 20 of out 389
# Matching ('chiapas', 'suchiate'), combination 21 of out 389
# Matching ('chiapas', 'tapachula'), combination 22 of out 389
# Matching ('chiapas', 'tuxtla_gutierrez'), combination 23 of out 389
# Matching ('chihuahua', 'aquiles_serdan'), combination 24 of out 389
# Matching ('chihuahua', 'camargo'), combination 25 of out 389
# Matching ('chihuahua', 'chihuahua'), combination 26 of out 389
# Matching ('chihuahua', 'chinipas'), combination 27 of out 389
# Matching ('chihuahua', 'cuauhtemoc'), combination 28 of out 389
# Matching ('chihuahua', 'delicias'), combination 29 of out 389
# Matching ('chihuahua', 'guerrero'), combination 30 of out 389
# Matching ('chihuahua', 'hidalgo_del_parral'), combination 31 of out 389
# Matching ('chihuahua', 'juarez'), combination 32 of out 389
# Matching ('chihuahua', 'nuevo_casas_grandes'), combination 33 of out 389
# Matching ('chihuahua', 'ocampo'), combination 34 of out 389
# Matching ('chihuahua', 'ojinaga'), combination 35 of out 389
# Matching ('chihuahua', 'riva_palacio'), combination 36 of out 389
# Matching ('chihuahua', 'satevo'), combination 37 of out 389
# Matching ('chihuahua', 'urique'), combination 38 of out 389
# Matching ('ciudad_de_mexico', 'alvaro_obregon'), combination 39 of out 389
# Matching ('ciudad_de_mexico', 'azcapotzalco'), combination 40 of out 389
# Matching ('ciudad_de_mexico', 'benito_juarez'), combination 41 of out 389
# Matching ('ciudad_de_mexico', 'coyoacan'), combination 42 of out 389
# Matching ('ciudad_de_mexico', 'cuajimalpa_de_morelos'), combination 43 of out 389
# Matching ('ciudad_de_mexico', 'cuauhtemoc'), combination 44 of out 389
# Matching ('ciudad_de_mexico', 'gustavo_a._madero'), combination 45 of out 389
# Matching ('ciudad_de_mexico', 'iztacalco'), combination 46 of out 389
# Matching ('ciudad_de_mexico', 'iztapalapa'), combination 47 of out 389
# Matching ('ciudad_de_mexico', 'la_magdalena_contreras'), combination 48 of out 389
# Matching ('ciudad_de_mexico', 'miguel_hidalgo'), combination 49 of out 389
# Matching ('ciudad_de_mexico', 'tlahuac'), combination 50 of out 389
# Matching ('ciudad_de_mexico', 'tlalpan'), combination 51 of out 389
# Matching ('ciudad_de_mexico', 'venustiano_carranza'), combination 52 of out 389
# Matching ('ciudad_de_mexico', 'xochimilco'), combination 53 of out 389
# Matching ('coahuila_de_zaragoza', 'acuna'), combination 54 of out 389
# Matching ('coahuila_de_zaragoza', 'arteaga'), combination 55 of out 389
# Matching ('coahuila_de_zaragoza', 'castanos'), combination 56 of out 389
# Matching ('coahuila_de_zaragoza', 'frontera'), combination 57 of out 389
# Matching ('coahuila_de_zaragoza', 'matamoros'), combination 58 of out 389
# Matching ('coahuila_de_zaragoza', 'monclova'), combination 59 of out 389
# Matching ('coahuila_de_zaragoza', 'muzquiz'), combination 60 of out 389
# Matching ('coahuila_de_zaragoza', 'nava'), combination 61 of out 389
# Matching ('coahuila_de_zaragoza', 'parras'), combination 62 of out 389
# Matching ('coahuila_de_zaragoza', 'piedras_negras'), combination 63 of out 389
# Matching ('coahuila_de_zaragoza', 'ramos_arizpe'), combination 64 of out 389
# Matching ('coahuila_de_zaragoza', 'sabinas'), combination 65 of out 389
# Matching ('coahuila_de_zaragoza', 'saltillo'), combination 66 of out 389
# Matching ('coahuila_de_zaragoza', 'san_buenaventura'), combination 67 of out 389
# Matching ('coahuila_de_zaragoza', 'san_juan_de_sabinas'), combination 68 of out 389
# Matching ('coahuila_de_zaragoza', 'san_pedro'), combination 69 of out 389
# Matching ('coahuila_de_zaragoza', 'sierra_mojada'), combination 70 of out 389
# Matching ('coahuila_de_zaragoza', 'torreon'), combination 71 of out 389
# Matching ('coahuila_de_zaragoza', 'viesca'), combination 72 of out 389
# Matching ('coahuila_de_zaragoza', 'zaragoza'), combination 73 of out 389
# Matching ('colima', 'colima'), combination 74 of out 389
# Matching ('colima', 'cuauhtemoc'), combination 75 of out 389
# Matching ('colima', 'manzanillo'), combination 76 of out 389
# Matching ('colima', 'tecoman'), combination 77 of out 389
# Matching ('durango', 'durango'), combination 78 of out 389
# Matching ('durango', 'gomez_palacio'), combination 79 of out 389
# Matching ('durango', 'guadalupe_victoria'), combination 80 of out 389
# Matching ('durango', 'guanacevi'), combination 81 of out 389
# Matching ('durango', 'mapimi'), combination 82 of out 389
# Matching ('durango', 'nombre_de_dios'), combination 83 of out 389
# Matching ('durango', 'pueblo_nuevo'), combination 84 of out 389
# Matching ('durango', 'san_dimas'), combination 85 of out 389
# Matching ('durango', 'topia'), combination 86 of out 389
# Matching ('guanajuato', 'abasolo'), combination 87 of out 389
# Matching ('guanajuato', 'acambaro'), combination 88 of out 389
# Matching ('guanajuato', 'apaseo_el_grande'), combination 89 of out 389
# Matching ('guanajuato', 'celaya'), combination 90 of out 389
# Matching ('guanajuato', 'cortazar'), combination 91 of out 389
# Matching ('guanajuato', 'guanajuato'), combination 92 of out 389
# Matching ('guanajuato', 'irapuato'), combination 93 of out 389
# Matching ('guanajuato', 'leon'), combination 94 of out 389
# Matching ('guanajuato', 'purisima_del_rincon'), combination 95 of out 389
# Matching ('guanajuato', 'romita'), combination 96 of out 389
# Matching ('guanajuato', 'salamanca'), combination 97 of out 389
# Matching ('guanajuato', 'san_francisco_del_rincon'), combination 98 of out 389
# Matching ('guanajuato', 'san_jose_iturbide'), combination 99 of out 389
# Matching ('guanajuato', 'san_luis_de_la_paz'), combination 100 of out 389
# Matching ('guanajuato', 'san_miguel_de_allende'), combination 101 of out 389
# Matching ('guanajuato', 'silao_de_la_victoria'), combination 102 of out 389
# Matching ('guanajuato', 'valle_de_santiago'), combination 103 of out 389
# Matching ('guanajuato', 'villagran'), combination 104 of out 389
# Matching ('guerrero', 'acapulco_de_juarez'), combination 105 of out 389
# Matching ('guerrero', 'chilpancingo_de_los_bravo'), combination 106 of out 389
# Matching ('guerrero', 'pungarabato'), combination 107 of out 389
# Matching ('guerrero', 'zihuatanejo_de_azueta'), combination 108 of out 389
# Matching ('hidalgo', 'atitalaquia'), combination 109 of out 389
# Matching ('hidalgo', 'atotonilco_de_tula'), combination 110 of out 389
# Matching ('hidalgo', 'huejutla_de_reyes'), combination 111 of out 389
# Matching ('hidalgo', 'huichapan'), combination 112 of out 389
# Matching ('hidalgo', 'pachuca_de_soto'), combination 113 of out 389
# Matching ('hidalgo', 'santiago_tulantepec_de_lugo_guerrero_hidalgo'), combination 114 of out 389
# Matching ('hidalgo', 'tepeapulco'), combination 115 of out 389
# Matching ('hidalgo', 'tepeji_del_rio_de_ocampo'), combination 116 of out 389
# Matching ('hidalgo', 'tizayuca'), combination 117 of out 389
# Matching ('hidalgo', 'tlanalapa'), combination 118 of out 389
# Matching ('jalisco', 'acatlan_de_juarez'), combination 119 of out 389
# Matching ('jalisco', 'amatitan'), combination 120 of out 389
# Matching ('jalisco', 'ameca'), combination 121 of out 389
# Matching ('jalisco', 'arandas'), combination 122 of out 389
# Matching ('jalisco', 'atengo'), combination 123 of out 389
# Matching ('jalisco', 'atotonilco_el_alto'), combination 124 of out 389
# Matching ('jalisco', 'autlan_de_navarro'), combination 125 of out 389
# Matching ('jalisco', 'canadas_de_obregon'), combination 126 of out 389
# Matching ('jalisco', 'chapala'), combination 127 of out 389
# Matching ('jalisco', 'cocula'), combination 128 of out 389
# Matching ('jalisco', 'degollado'), combination 129 of out 389
# Matching ('jalisco', 'el_salto'), combination 130 of out 389
# Matching ('jalisco', 'guadalajara'), combination 131 of out 389
# Matching ('jalisco', 'ixtlahuacan_de_los_membrillos'), combination 132 of out 389
# Matching ('jalisco', 'jamay'), combination 133 of out 389
# Matching ('jalisco', 'jesus_maria'), combination 134 of out 389
# Matching ('jalisco', 'lagos_de_moreno'), combination 135 of out 389
# Matching ('jalisco', 'ocotlan'), combination 136 of out 389
# Matching ('jalisco', 'ojuelos_de_jalisco'), combination 137 of out 389
# Matching ('jalisco', 'poncitlan'), combination 138 of out 389
# Matching ('jalisco', 'puerto_vallarta'), combination 139 of out 389
# Matching ('jalisco', 'san_diego_de_alejandria'), combination 140 of out 389
# Matching ('jalisco', 'san_martin_de_bolanos'), combination 141 of out 389
# Matching ('jalisco', 'san_pedro_tlaquepaque'), combination 142 of out 389
# Matching ('jalisco', 'tala'), combination 143 of out 389
# Matching ('jalisco', 'tamazula_de_gordiano'), combination 144 of out 389
# Matching ('jalisco', 'tepatitlan_de_morelos'), combination 145 of out 389
# Matching ('jalisco', 'tequila'), combination 146 of out 389
# Matching ('jalisco', 'tlajomulco_de_zuniga'), combination 147 of out 389
# Matching ('jalisco', 'toliman'), combination 148 of out 389
# Matching ('jalisco', 'tonala'), combination 149 of out 389
# Matching ('jalisco', 'zacoalco_de_torres'), combination 150 of out 389
# Matching ('jalisco', 'zapopan'), combination 151 of out 389
# Matching ('jalisco', 'zapotiltic'), combination 152 of out 389
# Matching ('jalisco', 'zapotlan_el_grande'), combination 153 of out 389
# Matching ('mexico', 'apaxco'), combination 154 of out 389
# Matching ('mexico', 'atizapan_de_zaragoza'), combination 155 of out 389
# Matching ('mexico', 'atlacomulco'), combination 156 of out 389
# Matching ('mexico', 'capulhuac'), combination 157 of out 389
# Matching ('mexico', 'chalco'), combination 158 of out 389
# Matching ('mexico', 'coacalco_de_berriozabal'), combination 159 of out 389
# Matching ('mexico', 'cuautitlan'), combination 160 of out 389
# Matching ('mexico', 'ecatepec_de_morelos'), combination 161 of out 389
# Matching ('mexico', 'huehuetoca'), combination 162 of out 389
# Matching ('mexico', 'huixquilucan'), combination 163 of out 389
# Matching ('mexico', 'ixtapaluca'), combination 164 of out 389
# Matching ('mexico', 'ixtlahuaca'), combination 165 of out 389
# Matching ('mexico', 'jilotepec'), combination 166 of out 389
# Matching ('mexico', 'jocotitlan'), combination 167 of out 389
# Matching ('mexico', 'la_paz'), combination 168 of out 389
# Matching ('mexico', 'lerma'), combination 169 of out 389
# Matching ('mexico', 'metepec'), combination 170 of out 389
# Matching ('mexico', 'mexicaltzingo'), combination 171 of out 389
# Matching ('mexico', 'morelos'), combination 172 of out 389
# Matching ('mexico', 'naucalpan_de_juarez'), combination 173 of out 389
# Matching ('mexico', 'nezahualcoyotl'), combination 174 of out 389
# Matching ('mexico', 'nicolas_romero'), combination 175 of out 389
# Matching ('mexico', 'ocoyoacac'), combination 176 of out 389
# Matching ('mexico', 'ocuilan'), combination 177 of out 389
# Matching ('mexico', 'san_mateo_atenco'), combination 178 of out 389
# Matching ('mexico', 'tecamac'), combination 179 of out 389
# Matching ('mexico', 'temascalcingo'), combination 180 of out 389
# Matching ('mexico', 'temascaltepec'), combination 181 of out 389
# Matching ('mexico', 'tepotzotlan'), combination 182 of out 389
# Matching ('mexico', 'texcoco'), combination 183 of out 389
# Matching ('mexico', 'tezoyuca'), combination 184 of out 389
# Matching ('mexico', 'tianguistenco'), combination 185 of out 389
# Matching ('mexico', 'tlalnepantla_de_baz'), combination 186 of out 389
# Matching ('mexico', 'toluca'), combination 187 of out 389
# Matching ('mexico', 'tultepec'), combination 188 of out 389
# Matching ('mexico', 'tultitlan'), combination 189 of out 389
# Matching ('mexico', 'villa_guerrero'), combination 190 of out 389
# Matching ('mexico', 'zacualpan'), combination 191 of out 389
# Matching ('mexico', 'zinacantepec'), combination 192 of out 389
# Matching ('mexico', 'zumpango'), combination 193 of out 389
# Matching ('michoacan_de_ocampo', 'jacona'), combination 194 of out 389
# Matching ('michoacan_de_ocampo', 'la_piedad'), combination 195 of out 389
# Matching ('michoacan_de_ocampo', 'lazaro_cardenas'), combination 196 of out 389
# Matching ('michoacan_de_ocampo', 'los_reyes'), combination 197 of out 389
# Matching ('michoacan_de_ocampo', 'morelia'), combination 198 of out 389
# Matching ('michoacan_de_ocampo', 'morelos'), combination 199 of out 389
# Matching ('michoacan_de_ocampo', 'mugica'), combination 200 of out 389
# Matching ('michoacan_de_ocampo', 'periban'), combination 201 of out 389
# Matching ('michoacan_de_ocampo', 'tinguindin'), combination 202 of out 389
# Matching ('michoacan_de_ocampo', 'tocumbo'), combination 203 of out 389
# Matching ('michoacan_de_ocampo', 'uruapan'), combination 204 of out 389
# Matching ('michoacan_de_ocampo', 'zacapu'), combination 205 of out 389
# Matching ('michoacan_de_ocampo', 'zamora'), combination 206 of out 389
# Matching ('morelos', 'ayala'), combination 207 of out 389
# Matching ('morelos', 'cuautla'), combination 208 of out 389
# Matching ('morelos', 'cuernavaca'), combination 209 of out 389
# Matching ('morelos', 'emiliano_zapata'), combination 210 of out 389
# Matching ('morelos', 'jiutepec'), combination 211 of out 389
# Matching ('morelos', 'tepoztlan'), combination 212 of out 389
# Matching ('morelos', 'xochitepec'), combination 213 of out 389
# Matching ('morelos', 'yautepec'), combination 214 of out 389
# Matching ('morelos', 'yecapixtla'), combination 215 of out 389
# Matching ('nayarit', 'bahia_de_banderas'), combination 216 of out 389
# Matching ('nayarit', 'ixtlan_del_rio'), combination 217 of out 389
# Matching ('nayarit', 'tepic'), combination 218 of out 389
# Matching ('nuevo_leon', 'abasolo'), combination 219 of out 389
# Matching ('nuevo_leon', 'apodaca'), combination 220 of out 389
# Matching ('nuevo_leon', 'cadereyta_jimenez'), combination 221 of out 389
# Matching ('nuevo_leon', 'cienega_de_flores'), combination 222 of out 389
# Matching ('nuevo_leon', 'doctor_gonzalez'), combination 223 of out 389
# Matching ('nuevo_leon', 'el_carmen'), combination 224 of out 389
# Matching ('nuevo_leon', 'garcia'), combination 225 of out 389
# Matching ('nuevo_leon', 'general_escobedo'), combination 226 of out 389
# Matching ('nuevo_leon', 'general_teran'), combination 227 of out 389
# Matching ('nuevo_leon', 'guadalupe'), combination 228 of out 389
# Matching ('nuevo_leon', 'juarez'), combination 229 of out 389
# Matching ('nuevo_leon', 'linares'), combination 230 of out 389
# Matching ('nuevo_leon', 'los_ramones'), combination 231 of out 389
# Matching ('nuevo_leon', 'montemorelos'), combination 232 of out 389
# Matching ('nuevo_leon', 'monterrey'), combination 233 of out 389
# Matching ('nuevo_leon', 'pesqueria'), combination 234 of out 389
# Matching ('nuevo_leon', 'sabinas_hidalgo'), combination 235 of out 389
# Matching ('nuevo_leon', 'salinas_victoria'), combination 236 of out 389
# Matching ('nuevo_leon', 'san_nicolas_de_los_garza'), combination 237 of out 389
# Matching ('nuevo_leon', 'san_pedro_garza_garcia'), combination 238 of out 389
# Matching ('nuevo_leon', 'santa_catarina'), combination 239 of out 389
# Matching ('oaxaca', 'ciudad_ixtepec'), combination 240 of out 389
# Matching ('oaxaca', 'heroica_ciudad_de_juchitan_de_zaragoza'), combination 241 of out 389
# Matching ('oaxaca', 'miahuatlan_de_porfirio_diaz'), combination 242 of out 389
# Matching ('oaxaca', 'oaxaca_de_juarez'), combination 243 of out 389
# Matching ('oaxaca', 'salina_cruz'), combination 244 of out 389
# Matching ('oaxaca', 'san_jacinto_amilpas'), combination 245 of out 389
# Matching ('oaxaca', 'san_juan_bautista_tuxtepec'), combination 246 of out 389
# Matching ('oaxaca', 'santa_cruz_xoxocotlan'), combination 247 of out 389
# Matching ('oaxaca', 'santa_lucia_del_camino'), combination 248 of out 389
# Matching ('oaxaca', 'santa_maria_huatulco'), combination 249 of out 389
# Matching ('oaxaca', 'teotitlan_del_valle'), combination 250 of out 389
# Matching ('puebla', 'amozoc'), combination 251 of out 389
# Matching ('puebla', 'atzala'), combination 252 of out 389
# Matching ('puebla', 'coronango'), combination 253 of out 389
# Matching ('puebla', 'cuautlancingo'), combination 254 of out 389
# Matching ('puebla', 'huejotzingo'), combination 255 of out 389
# Matching ('puebla', 'jalpan'), combination 256 of out 389
# Matching ('puebla', 'puebla'), combination 257 of out 389
# Matching ('puebla', 'quecholac'), combination 258 of out 389
# Matching ('puebla', 'san_andres_cholula'), combination 259 of out 389
# Matching ('puebla', 'san_gregorio_atzompa'), combination 260 of out 389
# Matching ('puebla', 'san_miguel_xoxtla'), combination 261 of out 389
# Matching ('puebla', 'san_pedro_cholula'), combination 262 of out 389
# Matching ('puebla', 'santa_isabel_cholula'), combination 263 of out 389
# Matching ('puebla', 'tehuacan'), combination 264 of out 389
# Matching ('puebla', 'tepanco_de_lopez'), combination 265 of out 389
# Matching ('puebla', 'tlahuapan'), combination 266 of out 389
# Matching ('puebla', 'zacatlan'), combination 267 of out 389
# Matching ('queretaro', 'cadereyta_de_montes'), combination 268 of out 389
# Matching ('queretaro', 'colon'), combination 269 of out 389
# Matching ('queretaro', 'corregidora'), combination 270 of out 389
# Matching ('queretaro', 'el_marques'), combination 271 of out 389
# Matching ('queretaro', 'ezequiel_montes'), combination 272 of out 389
# Matching ('queretaro', 'huimilpan'), combination 273 of out 389
# Matching ('queretaro', 'pedro_escobedo'), combination 274 of out 389
# Matching ('queretaro', 'queretaro'), combination 275 of out 389
# Matching ('queretaro', 'san_juan_del_rio'), combination 276 of out 389
# Matching ('queretaro', 'tequisquiapan'), combination 277 of out 389
# Matching ('queretaro', 'toliman'), combination 278 of out 389
# Matching ('quintana_roo', 'benito_juarez'), combination 279 of out 389
# Matching ('quintana_roo', 'cozumel'), combination 280 of out 389
# Matching ('quintana_roo', 'lazaro_cardenas'), combination 281 of out 389
# Matching ('quintana_roo', 'solidaridad'), combination 282 of out 389
# Matching ('quintana_roo', 'tulum'), combination 283 of out 389
# Matching ('san_luis_potosi', 'cardenas'), combination 284 of out 389
# Matching ('san_luis_potosi', 'cerro_de_san_pedro'), combination 285 of out 389
# Matching ('san_luis_potosi', 'ciudad_valles'), combination 286 of out 389
# Matching ('san_luis_potosi', 'matehuala'), combination 287 of out 389
# Matching ('san_luis_potosi', 'mexquitic_de_carmona'), combination 288 of out 389
# Matching ('san_luis_potosi', 'rioverde'), combination 289 of out 389
# Matching ('san_luis_potosi', 'san_luis_potosi'), combination 290 of out 389
# Matching ('san_luis_potosi', 'santa_maria_del_rio'), combination 291 of out 389
# Matching ('san_luis_potosi', 'soledad_de_graciano_sanchez'), combination 292 of out 389
# Matching ('san_luis_potosi', 'tamasopo'), combination 293 of out 389
# Matching ('san_luis_potosi', 'tamuin'), combination 294 of out 389
# Matching ('san_luis_potosi', 'villa_de_reyes'), combination 295 of out 389
# Matching ('sinaloa', 'ahome'), combination 296 of out 389
# Matching ('sinaloa', 'concordia'), combination 297 of out 389
# Matching ('sinaloa', 'culiacan'), combination 298 of out 389
# Matching ('sinaloa', 'guasave'), combination 299 of out 389
# Matching ('sinaloa', 'mazatlan'), combination 300 of out 389
# Matching ('sinaloa', 'navolato'), combination 301 of out 389
# Matching ('sinaloa', 'salvador_alvarado'), combination 302 of out 389
# Matching ('sonora', 'agua_prieta'), combination 303 of out 389
# Matching ('sonora', 'alamos'), combination 304 of out 389
# Matching ('sonora', 'banamichi'), combination 305 of out 389
# Matching ('sonora', 'caborca'), combination 306 of out 389
# Matching ('sonora', 'cajeme'), combination 307 of out 389
# Matching ('sonora', 'cananea'), combination 308 of out 389
# Matching ('sonora', 'guaymas'), combination 309 of out 389
# Matching ('sonora', 'hermosillo'), combination 310 of out 389
# Matching ('sonora', 'huatabampo'), combination 311 of out 389
# Matching ('sonora', 'la_colorada'), combination 312 of out 389
# Matching ('sonora', 'magdalena'), combination 313 of out 389
# Matching ('sonora', 'naco'), combination 314 of out 389
# Matching ('sonora', 'navojoa'), combination 315 of out 389
# Matching ('sonora', 'nogales'), combination 316 of out 389
# Matching ('sonora', 'pitiquito'), combination 317 of out 389
# Matching ('sonora', 'sahuaripa'), combination 318 of out 389
# Matching ('sonora', 'san_luis_rio_colorado'), combination 319 of out 389
# Matching ('sonora', 'san_miguel_de_horcasitas'), combination 320 of out 389
# Matching ('tabasco', 'cardenas'), combination 321 of out 389
# Matching ('tabasco', 'centro'), combination 322 of out 389
# Matching ('tabasco', 'cunduacan'), combination 323 of out 389
# Matching ('tabasco', 'macuspana'), combination 324 of out 389
# Matching ('tamaulipas', 'altamira'), combination 325 of out 389
# Matching ('tamaulipas', 'camargo'), combination 326 of out 389
# Matching ('tamaulipas', 'ciudad_madero'), combination 327 of out 389
# Matching ('tamaulipas', 'el_mante'), combination 328 of out 389
# Matching ('tamaulipas', 'gonzalez'), combination 329 of out 389
# Matching ('tamaulipas', 'matamoros'), combination 330 of out 389
# Matching ('tamaulipas', 'nuevo_laredo'), combination 331 of out 389
# Matching ('tamaulipas', 'reynosa'), combination 332 of out 389
# Matching ('tamaulipas', 'rio_bravo'), combination 333 of out 389
# Matching ('tamaulipas', 'san_fernando'), combination 334 of out 389
# Matching ('tamaulipas', 'tampico'), combination 335 of out 389
# Matching ('tamaulipas', 'valle_hermoso'), combination 336 of out 389
# Matching ('tamaulipas', 'victoria'), combination 337 of out 389
# Matching ('tamaulipas', 'xicotencatl'), combination 338 of out 389
# Matching ('tlaxcala', 'acuamanala_de_miguel_hidalgo'), combination 339 of out 389
# Matching ('tlaxcala', 'apizaco'), combination 340 of out 389
# Matching ('tlaxcala', 'calpulalpan'), combination 341 of out 389
# Matching ('tlaxcala', 'huamantla'), combination 342 of out 389
# Matching ('tlaxcala', 'ixtacuixtla_de_mariano_matamoros'), combination 343 of out 389
# Matching ('tlaxcala', 'nativitas'), combination 344 of out 389
# Matching ('tlaxcala', 'papalotla_de_xicohtencatl'), combination 345 of out 389
# Matching ('tlaxcala', 'san_pablo_del_monte'), combination 346 of out 389
# Matching ('tlaxcala', 'santa_isabel_xiloxoxtla'), combination 347 of out 389
# Matching ('tlaxcala', 'tetla_de_la_solidaridad'), combination 348 of out 389
# Matching ('tlaxcala', 'tlaxcala'), combination 349 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'amatlan_de_los_reyes'), combination 350 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'banderilla'), combination 351 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'boca_del_rio'), combination 352 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'coatzacoalcos'), combination 353 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'cordoba'), combination 354 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'el_higo'), combination 355 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'espinal'), combination 356 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'hueyapan_de_ocampo'), combination 357 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'isla'), combination 358 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'ixtaczoquitlan'), combination 359 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'las_vigas_de_ramirez'), combination 360 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'naranjos_amatlan'), combination 361 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'orizaba'), combination 362 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'panuco'), combination 363 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'perote'), combination 364 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'poza_rica_de_hidalgo'), combination 365 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'pueblo_viejo'), combination 366 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'san_juan_evangelista'), combination 367 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'tierra_blanca'), combination 368 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'tihuatlan'), combination 369 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'tuxpan'), combination 370 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'veracruz'), combination 371 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'xalapa'), combination 372 of out 389
# Matching ('veracruz_de_ignacio_de_la_llave', 'yanga'), combination 373 of out 389
# Matching ('yucatan', 'kanasin'), combination 374 of out 389
# Matching ('yucatan', 'merida'), combination 375 of out 389
# Matching ('yucatan', 'progreso'), combination 376 of out 389
# Matching ('yucatan', 'ticul'), combination 377 of out 389
# Matching ('yucatan', 'tixkokob'), combination 378 of out 389
# Matching ('yucatan', 'uman'), combination 379 of out 389
# Matching ('zacatecas', 'calera'), combination 380 of out 389
# Matching ('zacatecas', 'chalchihuites'), combination 381 of out 389
# Matching ('zacatecas', 'fresnillo'), combination 382 of out 389
# Matching ('zacatecas', 'guadalupe'), combination 383 of out 389
# Matching ('zacatecas', 'jerez'), combination 384 of out 389
# Matching ('zacatecas', 'juan_aldama'), combination 385 of out 389
# Matching ('zacatecas', 'morelos'), combination 386 of out 389
# Matching ('zacatecas', 'ojocaliente'), combination 387 of out 389
# Matching ('zacatecas', 'rio_grande'), combination 388 of out 389
# Matching ('zacatecas', 'zacatecas'), combination 389 of out 389

# %% [markdown]
# # Concatenate and save results
# First, we concatenate all the files with the prefix `output_file_prefix`, then we label them by algorithm and DENUE's geographical selection, finally, we drop duplicate matches and save it.

# %%
joint_matches = pd.concat([pd.read_csv(f) for f in 
                           glob.glob(output_file_prefix +'*.csv')], ignore_index=True) # concatenate the results
joint_matches['algorithm'] = 'rapidfuzz' # label the algorithm
joint_matches['selection'] = 'both_entity_municipality_alternative' # label the database selection
joint_matches.drop_duplicates(ignore_index = True).to_csv(final_output, index = False) # drop duplicates and save
