# %% [markdown]
# # TF-IDF Vectorizer 2-3 ngrams Cosine Similarity
# ## Controlling ORBIS by entity and municipality and DENUE by entity and municipality

# %% [markdown]
# # General information
# This notebook mainly executes the following for the firm names in `denue_final` and `orbis_final`:
#
# - Filtering the desired geographical zones in both data sets.
# - Extracting the company names.
# - Training the algorithm.
# - Extracting the results.
# - Labeling the results.
# - Exporting them to a Comma Separated Values file.
#
# After this, we've got the possible name matches in `denue_final` for each company in `orbis_final`.

# %% [markdown]
# # Input files
# 1. **orbis_final:** `'/scratch/public/jpvasquez/MNCs_informality/Intermediate_data/output/orbis_final.csv'` This file contains a data set where each row represents a firm with one of their names associated, also, entity, municipality and ORBIS's BVDID number.
# 2. **denue_final_alternative:** `'/scratch/public/jpvasquez/MNCs_informality/Intermediate_data/output/denue_final_alternative.csv'` This file contains a dataset where each row represents a firm with one of their names associated, also, the number of workers in that firm, entity, municipality and DENUE's key.

# %%
orbis_final_file = '/scratch/public/jpvasquez/MNCs_informality/Intermediate_data/output/orbis_final.csv'
denue_final_alternative_file = '/scratch/public/jpvasquez/MNCs_informality/Intermediate_data/output/denue_final_alternative.csv'

# %% [markdown]
# # Output files
# 1. **output_file_prefix:** `'/scratch/public/jpvasquez/MNCs_informality/Final_data/output/both_entity_municipality/denue_alternative/tf-idf/matches_tf_idf_both_'` These files contain the possible matches of each municipality.
# 2. **final_output:** `'/scratch/public/jpvasquez/MNCs_informality/Final_data/output/2-1-2-1-matches_tf_idf_both_entity_municipality_alternative.csv'` This file is a concatenation of all the `output_file_prefix` files.

# %%
output_file_prefix = '/scratch/public/jpvasquez/MNCs_informality/Final_data/output/both_entity_municipality/denue_alternative/tf-idf/matches_tf_idf_both_'
final_output = '/scratch/public/jpvasquez/MNCs_informality/Final_data/output/2-1-2-1-matches_tf_idf_both_entity_municipality_alternative.csv'

# %% [markdown]
# # Packages
# These are the needed packages to run this code. In case, the machine you're running this in doesn't have any of these packages, run this code:
#
# `!pip install package_name`
#
# - **Pandas** is the package which handles importing, wrangling, cleaning and doing everything with the data.
# - **Numpy** is needed in order to declare missing values.
# - **Glob** gets all the files from a directory with a prefix.
# - **Sklearn** is a package for machile learning, we'll use the module for Natural Language Processing.
# - **Scipy** is used for scientific computing, in our case, `csr_matrix` is a dependency of `awesome_cossim_topn`.
# - **Sparse_dot_topn** performs sparse matrix multiplication followed by top-n multiplication result selection.

# %%
import pandas as pd
import numpy as np
import glob
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import csr_matrix
from sparse_dot_topn import awesome_cossim_topn

# %% [markdown]
# # Importing the data

# %%
orbis_final = pd.read_csv(orbis_final_file)
denue_final = pd.read_csv(denue_final_alternative_file)

# %% [markdown]
# # Declaring options
# For customizability's sake, we'll group all the variables, options and arguments we could wish to change in the future. We'll make it in one cell, but feel free to split it into how many cells you want.

# %%
# base_df
base_data = orbis_final
category1 = 'entidad' # control 1 for groupby
category2 = 'municipio' # control 2 for groupby
# matching_df
matching_data = denue_final
base_names_variable = 'companyname' # control 1 for groupby
matching_names_variable = 'firm' # control 2 for groupby
# extracting the results
## top results
top_results_n = 100 # number of results of top quality
top_results_lower_bound = 0.95 # lowest score accepted for top quality matches
## uncertain results
uncertain_results_n = 300 # number of results of uncertain quality
uncertain_results_lower_bound = 0.75 # lowest score accepted for uncertain quality matches
uncertain_results_upper_bound = 0.95 # highest score accepted for uncertain quality matches
n_uncertain_results = 5 # top n results for uncertain matches
cores = 56 # subject to the number specified in the batch options
##################################
### don't change anything below###
##################################
categories = [category1, category2]

# %% [markdown]
# # Selecting the inner set of categories in `denue_final` and `orbis_final`
# - Get the unique categories tuples.
# - Keep the observations in each dataset that match the unique categories.

# %%
coincident_categories = (base_data[categories]
                         .drop_duplicates() # select the unique controlling variable combinations in base_data
                         .merge(matching_data[categories]
                                .drop_duplicates(), # select the unique controlling variable combinations in base_data
                                how = 'inner', left_on = categories, 
                                right_on = categories)) # merge 'inner' to get the pairs in both data sets

base_data = (base_data.merge(coincident_categories, how = 'inner', # keep the observations that
                             left_on = categories, right_on = categories)) #  match the inner unique categories
matching_data = matching_data.merge(coincident_categories, how = 'inner', # keep the observations that
                                    left_on = categories, right_on = categories)#  match the inner unique categories

# %% [markdown]
# # Matching algorithm
# Since this is a loop, we can't divide the algorithm in separate cells, so, we'll comment it with #.
# The main sections are:
#
# - Filter the datasets with their corresponding categories.
# - Get the company names.
# - Train the algorithm.
# - Extract the results.
#     - Top results.
#     - Uncertain results.
# - Save the matches.

# %%
i = 0
for base_group, base_df in base_data.groupby(by = categories): 
    i += 1
    print(f'Matching {base_group}, combination {i} out of 389')
    #########################
    ###Filter the datasets###
    #########################
    base_df = (base_df.copy()
               .dropna(subset = [base_names_variable]) # drop observations without variable name (firm name)
               .drop_duplicates(ignore_index=True)) # drop possible duplicates
    matching_df = (matching_data[(matching_data[category1] == base_group[0]) # filter the matching dataset
                                 & (matching_data[category2] == base_group[1])] # to match a category tuple
                   .copy() 
                   .dropna(subset = [matching_names_variable]) # drop observations without variable name (firm name)
                   .drop_duplicates(ignore_index=True)) # drop possible duplicates
    ######################################
    ###Getting variable (company) names###
    ######################################
    base_names = base_df[base_names_variable] # get the list of variable names (not necessarily unique) from base_df
    matching_names = matching_df[matching_names_variable] # get the list of variable names 
                                                          # (not necessarily unique) from matching_df
    names = base_names.append(matching_names, ignore_index=True) # concatenating both lists
    ############################
    ###Training the algorithm###
    ############################
    vectorizer = TfidfVectorizer(min_df = 1, ngram_range = (2, 3), analyzer = 'char') # call the function 
                                                                                      # at least one item, 2-3 ngrams, 
                                                                                      # by characters/letters
    tf_idf_matrix = vectorizer.fit(names) # train the models with all the company names from ORBIS and DENUE
    tf_idf_matrix_base = tf_idf_matrix.transform(base_names) # transform each observation into a vector 
                                                             # and append them into a matrix
    tf_idf_matrix_matching = tf_idf_matrix.transform(matching_names) # according to the ngrams
    ############################
    ###Extracting the results###
    ############################
    
    ############
    #Top results
    ############
    
    possible_matches = awesome_cossim_topn(tf_idf_matrix_base, # sparse matrix multiplication, base_df matrix
                                           tf_idf_matrix_matching.transpose(), # multiplied by the matching_df matrix
                                           top_results_n, top_results_lower_bound, use_threads = True, # options
                                           n_jobs = cores)
    
    possible_matches_base_df_index = possible_matches.nonzero()[0] # positions where the matches are located in base_df
    possible_matches_matching_df_index = possible_matches.nonzero()[1] # positions where the matches are located in matching_df
    
    certain_matches = (base_df.iloc[possible_matches_base_df_index] # create certain_matches df, merge the firm names of left side
                       .reset_index(drop = True) # select the observations by location, get index to 0, 1, ..., n
                       .merge(matching_df.iloc[possible_matches_matching_df_index] # select the observations by location
                              .reset_index(drop = True), left_index = True, # get index to 0, 1, ..., n
                              right_index = True)) # merge by index, 0 with 0, 1 with 1, ...
    certain_matches['score'] = possible_matches.data # assign score to each match
    certain_matches['accuracy'] = 'top' # tag them as top results
    
    ##################
    #Uncertain results
    ##################
    
    possible_matches = awesome_cossim_topn(tf_idf_matrix_base, # sparse matrix multiplication, base_df matrix
                                           tf_idf_matrix_matching.transpose(), # multiplied by the matching_df matrix
                                           uncertain_results_n, uncertain_results_lower_bound, use_threads = True, # options
                                           n_jobs = cores)
    
    possible_matches_base_df_index = possible_matches.nonzero()[0] # positions where the matches are located in base_df
    possible_matches_matching_df_index = possible_matches.nonzero()[1] # positions where the matches are located in matching_df
    
    uncertain_matches = (base_df.iloc[possible_matches_base_df_index] # create certain_matches df, merge the firm names of left side
                         .reset_index(drop = True) # select the observations by location, get index to 0, 1, ..., n
                         .merge(matching_df.iloc[possible_matches_matching_df_index] # select the observations by location
                                .reset_index(drop = True), left_index = True, # get index to 0, 1, ..., n
                                right_index = True)) # merge by index, 0 with 0, 1 with 1, ...
    uncertain_matches['score'] = possible_matches.data # assign score to each match
    uncertain_matches = (uncertain_matches[uncertain_matches['score'] < uncertain_results_upper_bound] # select the matches below upper bound
                         .sort_values(['score'], ascending = False) # sort values descending
                         .groupby('bvdidnumber').head(n_uncertain_results)) # group by bvdidnumber, then get the n best matches
    uncertain_matches['accuracy'] = 'uncertain' # tag them as uncertain results
    
    ########################
    ###Saving the matches###
    ########################
    
    matches = certain_matches.append(uncertain_matches, ignore_index = True) # append certain with uncertain matches
    file_name = output_file_prefix + base_group[0] + '_' + base_group[1] + '_alternative' +'.csv' # create file name
    matches.drop_duplicates(ignore_index = True).to_csv(file_name, index = False) # remove duplicates and save
# Out:
# Matching ('aguascalientes', 'aguascalientes'), combination 1 out of 398
# Matching ('aguascalientes', 'el_llano'), combination 2 out of 398
# Matching ('aguascalientes', 'jesus_maria'), combination 3 out of 398
# Matching ('aguascalientes', 'rincon_de_romos'), combination 4 out of 398
# Matching ('aguascalientes', 'san_francisco_de_los_romo'), combination 5 out of 398
# Matching ('baja_california', 'ensenada'), combination 6 out of 398
# Matching ('baja_california', 'mexicali'), combination 7 out of 398
# Matching ('baja_california', 'playas_de_rosarito'), combination 8 out of 398
# Matching ('baja_california', 'tecate'), combination 9 out of 398
# Matching ('baja_california', 'tijuana'), combination 10 out of 398
# Matching ('baja_california_sur', 'la_paz'), combination 11 out of 398
# Matching ('baja_california_sur', 'los_cabos'), combination 12 out of 398
# Matching ('baja_california_sur', 'mulege'), combination 13 out of 398
# Matching ('campeche', 'campeche'), combination 14 out of 398
# Matching ('campeche', 'carmen'), combination 15 out of 398
# Matching ('campeche', 'champoton'), combination 16 out of 398
# Matching ('campeche', 'hopelchen'), combination 17 out of 398
# Matching ('campeche', 'palizada'), combination 18 out of 398
# Matching ('chiapas', 'arriaga'), combination 19 out of 398
# Matching ('chiapas', 'palenque'), combination 20 out of 398
# Matching ('chiapas', 'suchiate'), combination 21 out of 398
# Matching ('chiapas', 'tapachula'), combination 22 out of 398
# Matching ('chiapas', 'tuxtla_gutierrez'), combination 23 out of 398
# Matching ('chihuahua', 'aquiles_serdan'), combination 24 out of 398
# Matching ('chihuahua', 'camargo'), combination 25 out of 398
# Matching ('chihuahua', 'chihuahua'), combination 26 out of 398
# Matching ('chihuahua', 'chinipas'), combination 27 out of 398
# Matching ('chihuahua', 'cuauhtemoc'), combination 28 out of 398
# Matching ('chihuahua', 'delicias'), combination 29 out of 398
# Matching ('chihuahua', 'guerrero'), combination 30 out of 398
# Matching ('chihuahua', 'hidalgo_del_parral'), combination 31 out of 398
# Matching ('chihuahua', 'juarez'), combination 32 out of 398
# Matching ('chihuahua', 'nuevo_casas_grandes'), combination 33 out of 398
# Matching ('chihuahua', 'ocampo'), combination 34 out of 398
# Matching ('chihuahua', 'ojinaga'), combination 35 out of 398
# Matching ('chihuahua', 'riva_palacio'), combination 36 out of 398
# Matching ('chihuahua', 'satevo'), combination 37 out of 398
# Matching ('chihuahua', 'urique'), combination 38 out of 398
# Matching ('ciudad_de_mexico', 'alvaro_obregon'), combination 39 out of 398
# Matching ('ciudad_de_mexico', 'azcapotzalco'), combination 40 out of 398
# Matching ('ciudad_de_mexico', 'benito_juarez'), combination 41 out of 398
# Matching ('ciudad_de_mexico', 'coyoacan'), combination 42 out of 398
# Matching ('ciudad_de_mexico', 'cuajimalpa_de_morelos'), combination 43 out of 398
# Matching ('ciudad_de_mexico', 'cuauhtemoc'), combination 44 out of 398
# Matching ('ciudad_de_mexico', 'gustavo_a._madero'), combination 45 out of 398
# Matching ('ciudad_de_mexico', 'iztacalco'), combination 46 out of 398
# Matching ('ciudad_de_mexico', 'iztapalapa'), combination 47 out of 398
# Matching ('ciudad_de_mexico', 'la_magdalena_contreras'), combination 48 out of 398
# Matching ('ciudad_de_mexico', 'miguel_hidalgo'), combination 49 out of 398
# Matching ('ciudad_de_mexico', 'tlahuac'), combination 50 out of 398
# Matching ('ciudad_de_mexico', 'tlalpan'), combination 51 out of 398
# Matching ('ciudad_de_mexico', 'venustiano_carranza'), combination 52 out of 398
# Matching ('ciudad_de_mexico', 'xochimilco'), combination 53 out of 398
# Matching ('coahuila_de_zaragoza', 'acuna'), combination 54 out of 398
# Matching ('coahuila_de_zaragoza', 'arteaga'), combination 55 out of 398
# Matching ('coahuila_de_zaragoza', 'castanos'), combination 56 out of 398
# Matching ('coahuila_de_zaragoza', 'frontera'), combination 57 out of 398
# Matching ('coahuila_de_zaragoza', 'matamoros'), combination 58 out of 398
# Matching ('coahuila_de_zaragoza', 'monclova'), combination 59 out of 398
# Matching ('coahuila_de_zaragoza', 'muzquiz'), combination 60 out of 398
# Matching ('coahuila_de_zaragoza', 'nava'), combination 61 out of 398
# Matching ('coahuila_de_zaragoza', 'parras'), combination 62 out of 398
# Matching ('coahuila_de_zaragoza', 'piedras_negras'), combination 63 out of 398
# Matching ('coahuila_de_zaragoza', 'ramos_arizpe'), combination 64 out of 398
# Matching ('coahuila_de_zaragoza', 'sabinas'), combination 65 out of 398
# Matching ('coahuila_de_zaragoza', 'saltillo'), combination 66 out of 398
# Matching ('coahuila_de_zaragoza', 'san_buenaventura'), combination 67 out of 398
# Matching ('coahuila_de_zaragoza', 'san_juan_de_sabinas'), combination 68 out of 398
# Matching ('coahuila_de_zaragoza', 'san_pedro'), combination 69 out of 398
# Matching ('coahuila_de_zaragoza', 'sierra_mojada'), combination 70 out of 398
# Matching ('coahuila_de_zaragoza', 'torreon'), combination 71 out of 398
# Matching ('coahuila_de_zaragoza', 'viesca'), combination 72 out of 398
# Matching ('coahuila_de_zaragoza', 'zaragoza'), combination 73 out of 398
# Matching ('colima', 'colima'), combination 74 out of 398
# Matching ('colima', 'cuauhtemoc'), combination 75 out of 398
# Matching ('colima', 'manzanillo'), combination 76 out of 398
# Matching ('colima', 'tecoman'), combination 77 out of 398
# Matching ('durango', 'durango'), combination 78 out of 398
# Matching ('durango', 'gomez_palacio'), combination 79 out of 398
# Matching ('durango', 'guadalupe_victoria'), combination 80 out of 398
# Matching ('durango', 'guanacevi'), combination 81 out of 398
# Matching ('durango', 'mapimi'), combination 82 out of 398
# Matching ('durango', 'nombre_de_dios'), combination 83 out of 398
# Matching ('durango', 'pueblo_nuevo'), combination 84 out of 398
# Matching ('durango', 'san_dimas'), combination 85 out of 398
# Matching ('durango', 'topia'), combination 86 out of 398
# Matching ('guanajuato', 'abasolo'), combination 87 out of 398
# Matching ('guanajuato', 'acambaro'), combination 88 out of 398
# Matching ('guanajuato', 'apaseo_el_grande'), combination 89 out of 398
# Matching ('guanajuato', 'celaya'), combination 90 out of 398
# Matching ('guanajuato', 'cortazar'), combination 91 out of 398
# Matching ('guanajuato', 'guanajuato'), combination 92 out of 398
# Matching ('guanajuato', 'irapuato'), combination 93 out of 398
# Matching ('guanajuato', 'leon'), combination 94 out of 398
# Matching ('guanajuato', 'purisima_del_rincon'), combination 95 out of 398
# Matching ('guanajuato', 'romita'), combination 96 out of 398
# Matching ('guanajuato', 'salamanca'), combination 97 out of 398
# Matching ('guanajuato', 'san_francisco_del_rincon'), combination 98 out of 398
# Matching ('guanajuato', 'san_jose_iturbide'), combination 99 out of 398
# Matching ('guanajuato', 'san_luis_de_la_paz'), combination 100 out of 398
# Matching ('guanajuato', 'san_miguel_de_allende'), combination 101 out of 398
# Matching ('guanajuato', 'silao_de_la_victoria'), combination 102 out of 398
# Matching ('guanajuato', 'valle_de_santiago'), combination 103 out of 398
# Matching ('guanajuato', 'villagran'), combination 104 out of 398
# Matching ('guerrero', 'acapulco_de_juarez'), combination 105 out of 398
# Matching ('guerrero', 'chilpancingo_de_los_bravo'), combination 106 out of 398
# Matching ('guerrero', 'pungarabato'), combination 107 out of 398
# Matching ('guerrero', 'zihuatanejo_de_azueta'), combination 108 out of 398
# Matching ('hidalgo', 'atitalaquia'), combination 109 out of 398
# Matching ('hidalgo', 'atotonilco_de_tula'), combination 110 out of 398
# Matching ('hidalgo', 'huejutla_de_reyes'), combination 111 out of 398
# Matching ('hidalgo', 'huichapan'), combination 112 out of 398
# Matching ('hidalgo', 'pachuca_de_soto'), combination 113 out of 398
# Matching ('hidalgo', 'santiago_tulantepec_de_lugo_guerrero_hidalgo'), combination 114 out of 398
# Matching ('hidalgo', 'tepeapulco'), combination 115 out of 398
# Matching ('hidalgo', 'tepeji_del_rio_de_ocampo'), combination 116 out of 398
# Matching ('hidalgo', 'tizayuca'), combination 117 out of 398
# Matching ('hidalgo', 'tlanalapa'), combination 118 out of 398
# Matching ('jalisco', 'acatlan_de_juarez'), combination 119 out of 398
# Matching ('jalisco', 'amatitan'), combination 120 out of 398
# Matching ('jalisco', 'ameca'), combination 121 out of 398
# Matching ('jalisco', 'arandas'), combination 122 out of 398
# Matching ('jalisco', 'atengo'), combination 123 out of 398
# Matching ('jalisco', 'atotonilco_el_alto'), combination 124 out of 398
# Matching ('jalisco', 'autlan_de_navarro'), combination 125 out of 398
# Matching ('jalisco', 'canadas_de_obregon'), combination 126 out of 398
# Matching ('jalisco', 'chapala'), combination 127 out of 398
# Matching ('jalisco', 'cocula'), combination 128 out of 398
# Matching ('jalisco', 'degollado'), combination 129 out of 398
# Matching ('jalisco', 'el_salto'), combination 130 out of 398
# Matching ('jalisco', 'guadalajara'), combination 131 out of 398
# Matching ('jalisco', 'ixtlahuacan_de_los_membrillos'), combination 132 out of 398
# Matching ('jalisco', 'jamay'), combination 133 out of 398
# Matching ('jalisco', 'jesus_maria'), combination 134 out of 398
# Matching ('jalisco', 'lagos_de_moreno'), combination 135 out of 398
# Matching ('jalisco', 'ocotlan'), combination 136 out of 398
# Matching ('jalisco', 'ojuelos_de_jalisco'), combination 137 out of 398
# Matching ('jalisco', 'poncitlan'), combination 138 out of 398
# Matching ('jalisco', 'puerto_vallarta'), combination 139 out of 398
# Matching ('jalisco', 'san_diego_de_alejandria'), combination 140 out of 398
# Matching ('jalisco', 'san_martin_de_bolanos'), combination 141 out of 398
# Matching ('jalisco', 'san_pedro_tlaquepaque'), combination 142 out of 398
# Matching ('jalisco', 'tala'), combination 143 out of 398
# Matching ('jalisco', 'tamazula_de_gordiano'), combination 144 out of 398
# Matching ('jalisco', 'tepatitlan_de_morelos'), combination 145 out of 398
# Matching ('jalisco', 'tequila'), combination 146 out of 398
# Matching ('jalisco', 'tlajomulco_de_zuniga'), combination 147 out of 398
# Matching ('jalisco', 'toliman'), combination 148 out of 398
# Matching ('jalisco', 'tonala'), combination 149 out of 398
# Matching ('jalisco', 'zacoalco_de_torres'), combination 150 out of 398
# Matching ('jalisco', 'zapopan'), combination 151 out of 398
# Matching ('jalisco', 'zapotiltic'), combination 152 out of 398
# Matching ('jalisco', 'zapotlan_el_grande'), combination 153 out of 398
# Matching ('mexico', 'apaxco'), combination 154 out of 398
# Matching ('mexico', 'atizapan_de_zaragoza'), combination 155 out of 398
# Matching ('mexico', 'atlacomulco'), combination 156 out of 398
# Matching ('mexico', 'capulhuac'), combination 157 out of 398
# Matching ('mexico', 'chalco'), combination 158 out of 398
# Matching ('mexico', 'coacalco_de_berriozabal'), combination 159 out of 398
# Matching ('mexico', 'cuautitlan'), combination 160 out of 398
# Matching ('mexico', 'ecatepec_de_morelos'), combination 161 out of 398
# Matching ('mexico', 'huehuetoca'), combination 162 out of 398
# Matching ('mexico', 'huixquilucan'), combination 163 out of 398
# Matching ('mexico', 'ixtapaluca'), combination 164 out of 398
# Matching ('mexico', 'ixtlahuaca'), combination 165 out of 398
# Matching ('mexico', 'jilotepec'), combination 166 out of 398
# Matching ('mexico', 'jocotitlan'), combination 167 out of 398
# Matching ('mexico', 'la_paz'), combination 168 out of 398
# Matching ('mexico', 'lerma'), combination 169 out of 398
# Matching ('mexico', 'metepec'), combination 170 out of 398
# Matching ('mexico', 'mexicaltzingo'), combination 171 out of 398
# Matching ('mexico', 'morelos'), combination 172 out of 398
# Matching ('mexico', 'naucalpan_de_juarez'), combination 173 out of 398
# Matching ('mexico', 'nezahualcoyotl'), combination 174 out of 398
# Matching ('mexico', 'nicolas_romero'), combination 175 out of 398
# Matching ('mexico', 'ocoyoacac'), combination 176 out of 398
# Matching ('mexico', 'ocuilan'), combination 177 out of 398
# Matching ('mexico', 'san_mateo_atenco'), combination 178 out of 398
# Matching ('mexico', 'tecamac'), combination 179 out of 398
# Matching ('mexico', 'temascalcingo'), combination 180 out of 398
# Matching ('mexico', 'temascaltepec'), combination 181 out of 398
# Matching ('mexico', 'tepotzotlan'), combination 182 out of 398
# Matching ('mexico', 'texcoco'), combination 183 out of 398
# Matching ('mexico', 'tezoyuca'), combination 184 out of 398
# Matching ('mexico', 'tianguistenco'), combination 185 out of 398
# Matching ('mexico', 'tlalnepantla_de_baz'), combination 186 out of 398
# Matching ('mexico', 'toluca'), combination 187 out of 398
# Matching ('mexico', 'tultepec'), combination 188 out of 398
# Matching ('mexico', 'tultitlan'), combination 189 out of 398
# Matching ('mexico', 'villa_guerrero'), combination 190 out of 398
# Matching ('mexico', 'zacualpan'), combination 191 out of 398
# Matching ('mexico', 'zinacantepec'), combination 192 out of 398
# Matching ('mexico', 'zumpango'), combination 193 out of 398
# Matching ('michoacan_de_ocampo', 'jacona'), combination 194 out of 398
# Matching ('michoacan_de_ocampo', 'la_piedad'), combination 195 out of 398
# Matching ('michoacan_de_ocampo', 'lazaro_cardenas'), combination 196 out of 398
# Matching ('michoacan_de_ocampo', 'los_reyes'), combination 197 out of 398
# Matching ('michoacan_de_ocampo', 'morelia'), combination 198 out of 398
# Matching ('michoacan_de_ocampo', 'morelos'), combination 199 out of 398
# Matching ('michoacan_de_ocampo', 'mugica'), combination 200 out of 398
# Matching ('michoacan_de_ocampo', 'periban'), combination 201 out of 398
# Matching ('michoacan_de_ocampo', 'tinguindin'), combination 202 out of 398
# Matching ('michoacan_de_ocampo', 'tocumbo'), combination 203 out of 398
# Matching ('michoacan_de_ocampo', 'uruapan'), combination 204 out of 398
# Matching ('michoacan_de_ocampo', 'zacapu'), combination 205 out of 398
# Matching ('michoacan_de_ocampo', 'zamora'), combination 206 out of 398
# Matching ('morelos', 'ayala'), combination 207 out of 398
# Matching ('morelos', 'cuautla'), combination 208 out of 398
# Matching ('morelos', 'cuernavaca'), combination 209 out of 398
# Matching ('morelos', 'emiliano_zapata'), combination 210 out of 398
# Matching ('morelos', 'jiutepec'), combination 211 out of 398
# Matching ('morelos', 'tepoztlan'), combination 212 out of 398
# Matching ('morelos', 'xochitepec'), combination 213 out of 398
# Matching ('morelos', 'yautepec'), combination 214 out of 398
# Matching ('morelos', 'yecapixtla'), combination 215 out of 398
# Matching ('nayarit', 'bahia_de_banderas'), combination 216 out of 398
# Matching ('nayarit', 'ixtlan_del_rio'), combination 217 out of 398
# Matching ('nayarit', 'tepic'), combination 218 out of 398
# Matching ('nuevo_leon', 'abasolo'), combination 219 out of 398
# Matching ('nuevo_leon', 'apodaca'), combination 220 out of 398
# Matching ('nuevo_leon', 'cadereyta_jimenez'), combination 221 out of 398
# Matching ('nuevo_leon', 'cienega_de_flores'), combination 222 out of 398
# Matching ('nuevo_leon', 'doctor_gonzalez'), combination 223 out of 398
# Matching ('nuevo_leon', 'el_carmen'), combination 224 out of 398
# Matching ('nuevo_leon', 'garcia'), combination 225 out of 398
# Matching ('nuevo_leon', 'general_escobedo'), combination 226 out of 398
# Matching ('nuevo_leon', 'general_teran'), combination 227 out of 398
# Matching ('nuevo_leon', 'guadalupe'), combination 228 out of 398
# Matching ('nuevo_leon', 'juarez'), combination 229 out of 398
# Matching ('nuevo_leon', 'linares'), combination 230 out of 398
# Matching ('nuevo_leon', 'los_ramones'), combination 231 out of 398
# Matching ('nuevo_leon', 'montemorelos'), combination 232 out of 398
# Matching ('nuevo_leon', 'monterrey'), combination 233 out of 398
# Matching ('nuevo_leon', 'pesqueria'), combination 234 out of 398
# Matching ('nuevo_leon', 'sabinas_hidalgo'), combination 235 out of 398
# Matching ('nuevo_leon', 'salinas_victoria'), combination 236 out of 398
# Matching ('nuevo_leon', 'san_nicolas_de_los_garza'), combination 237 out of 398
# Matching ('nuevo_leon', 'san_pedro_garza_garcia'), combination 238 out of 398
# Matching ('nuevo_leon', 'santa_catarina'), combination 239 out of 398
# Matching ('oaxaca', 'ciudad_ixtepec'), combination 240 out of 398
# Matching ('oaxaca', 'heroica_ciudad_de_juchitan_de_zaragoza'), combination 241 out of 398
# Matching ('oaxaca', 'miahuatlan_de_porfirio_diaz'), combination 242 out of 398
# Matching ('oaxaca', 'oaxaca_de_juarez'), combination 243 out of 398
# Matching ('oaxaca', 'salina_cruz'), combination 244 out of 398
# Matching ('oaxaca', 'san_jacinto_amilpas'), combination 245 out of 398
# Matching ('oaxaca', 'san_juan_bautista_tuxtepec'), combination 246 out of 398
# Matching ('oaxaca', 'santa_cruz_xoxocotlan'), combination 247 out of 398
# Matching ('oaxaca', 'santa_lucia_del_camino'), combination 248 out of 398
# Matching ('oaxaca', 'santa_maria_huatulco'), combination 249 out of 398
# Matching ('oaxaca', 'teotitlan_del_valle'), combination 250 out of 398
# Matching ('puebla', 'amozoc'), combination 251 out of 398
# Matching ('puebla', 'atzala'), combination 252 out of 398
# Matching ('puebla', 'coronango'), combination 253 out of 398
# Matching ('puebla', 'cuautlancingo'), combination 254 out of 398
# Matching ('puebla', 'huejotzingo'), combination 255 out of 398
# Matching ('puebla', 'jalpan'), combination 256 out of 398
# Matching ('puebla', 'puebla'), combination 257 out of 398
# Matching ('puebla', 'quecholac'), combination 258 out of 398
# Matching ('puebla', 'san_andres_cholula'), combination 259 out of 398
# Matching ('puebla', 'san_gregorio_atzompa'), combination 260 out of 398
# Matching ('puebla', 'san_miguel_xoxtla'), combination 261 out of 398
# Matching ('puebla', 'san_pedro_cholula'), combination 262 out of 398
# Matching ('puebla', 'santa_isabel_cholula'), combination 263 out of 398
# Matching ('puebla', 'tehuacan'), combination 264 out of 398
# Matching ('puebla', 'tepanco_de_lopez'), combination 265 out of 398
# Matching ('puebla', 'tlahuapan'), combination 266 out of 398
# Matching ('puebla', 'zacatlan'), combination 267 out of 398
# Matching ('queretaro', 'cadereyta_de_montes'), combination 268 out of 398
# Matching ('queretaro', 'colon'), combination 269 out of 398
# Matching ('queretaro', 'corregidora'), combination 270 out of 398
# Matching ('queretaro', 'el_marques'), combination 271 out of 398
# Matching ('queretaro', 'ezequiel_montes'), combination 272 out of 398
# Matching ('queretaro', 'huimilpan'), combination 273 out of 398
# Matching ('queretaro', 'pedro_escobedo'), combination 274 out of 398
# Matching ('queretaro', 'queretaro'), combination 275 out of 398
# Matching ('queretaro', 'san_juan_del_rio'), combination 276 out of 398
# Matching ('queretaro', 'tequisquiapan'), combination 277 out of 398
# Matching ('queretaro', 'toliman'), combination 278 out of 398
# Matching ('quintana_roo', 'benito_juarez'), combination 279 out of 398
# Matching ('quintana_roo', 'cozumel'), combination 280 out of 398
# Matching ('quintana_roo', 'lazaro_cardenas'), combination 281 out of 398
# Matching ('quintana_roo', 'solidaridad'), combination 282 out of 398
# Matching ('quintana_roo', 'tulum'), combination 283 out of 398
# Matching ('san_luis_potosi', 'cardenas'), combination 284 out of 398
# Matching ('san_luis_potosi', 'cerro_de_san_pedro'), combination 285 out of 398
# Matching ('san_luis_potosi', 'ciudad_valles'), combination 286 out of 398
# Matching ('san_luis_potosi', 'matehuala'), combination 287 out of 398
# Matching ('san_luis_potosi', 'mexquitic_de_carmona'), combination 288 out of 398
# Matching ('san_luis_potosi', 'rioverde'), combination 289 out of 398
# Matching ('san_luis_potosi', 'san_luis_potosi'), combination 290 out of 398
# Matching ('san_luis_potosi', 'santa_maria_del_rio'), combination 291 out of 398
# Matching ('san_luis_potosi', 'soledad_de_graciano_sanchez'), combination 292 out of 398
# Matching ('san_luis_potosi', 'tamasopo'), combination 293 out of 398
# Matching ('san_luis_potosi', 'tamuin'), combination 294 out of 398
# Matching ('san_luis_potosi', 'villa_de_reyes'), combination 295 out of 398
# Matching ('sinaloa', 'ahome'), combination 296 out of 398
# Matching ('sinaloa', 'concordia'), combination 297 out of 398
# Matching ('sinaloa', 'culiacan'), combination 298 out of 398
# Matching ('sinaloa', 'guasave'), combination 299 out of 398
# Matching ('sinaloa', 'mazatlan'), combination 300 out of 398
# Matching ('sinaloa', 'navolato'), combination 301 out of 398
# Matching ('sinaloa', 'salvador_alvarado'), combination 302 out of 398
# Matching ('sonora', 'agua_prieta'), combination 303 out of 398
# Matching ('sonora', 'alamos'), combination 304 out of 398
# Matching ('sonora', 'banamichi'), combination 305 out of 398
# Matching ('sonora', 'caborca'), combination 306 out of 398
# Matching ('sonora', 'cajeme'), combination 307 out of 398
# Matching ('sonora', 'cananea'), combination 308 out of 398
# Matching ('sonora', 'guaymas'), combination 309 out of 398
# Matching ('sonora', 'hermosillo'), combination 310 out of 398
# Matching ('sonora', 'huatabampo'), combination 311 out of 398
# Matching ('sonora', 'la_colorada'), combination 312 out of 398
# Matching ('sonora', 'magdalena'), combination 313 out of 398
# Matching ('sonora', 'naco'), combination 314 out of 398
# Matching ('sonora', 'navojoa'), combination 315 out of 398
# Matching ('sonora', 'nogales'), combination 316 out of 398
# Matching ('sonora', 'pitiquito'), combination 317 out of 398
# Matching ('sonora', 'sahuaripa'), combination 318 out of 398
# Matching ('sonora', 'san_luis_rio_colorado'), combination 319 out of 398
# Matching ('sonora', 'san_miguel_de_horcasitas'), combination 320 out of 398
# Matching ('tabasco', 'cardenas'), combination 321 out of 398
# Matching ('tabasco', 'centro'), combination 322 out of 398
# Matching ('tabasco', 'cunduacan'), combination 323 out of 398
# Matching ('tabasco', 'macuspana'), combination 324 out of 398
# Matching ('tamaulipas', 'altamira'), combination 325 out of 398
# Matching ('tamaulipas', 'camargo'), combination 326 out of 398
# Matching ('tamaulipas', 'ciudad_madero'), combination 327 out of 398
# Matching ('tamaulipas', 'el_mante'), combination 328 out of 398
# Matching ('tamaulipas', 'gonzalez'), combination 329 out of 398
# Matching ('tamaulipas', 'matamoros'), combination 330 out of 398
# Matching ('tamaulipas', 'nuevo_laredo'), combination 331 out of 398
# Matching ('tamaulipas', 'reynosa'), combination 332 out of 398
# Matching ('tamaulipas', 'rio_bravo'), combination 333 out of 398
# Matching ('tamaulipas', 'san_fernando'), combination 334 out of 398
# Matching ('tamaulipas', 'tampico'), combination 335 out of 398
# Matching ('tamaulipas', 'valle_hermoso'), combination 336 out of 398
# Matching ('tamaulipas', 'victoria'), combination 337 out of 398
# Matching ('tamaulipas', 'xicotencatl'), combination 338 out of 398
# Matching ('tlaxcala', 'acuamanala_de_miguel_hidalgo'), combination 339 out of 398
# Matching ('tlaxcala', 'apizaco'), combination 340 out of 398
# Matching ('tlaxcala', 'calpulalpan'), combination 341 out of 398
# Matching ('tlaxcala', 'huamantla'), combination 342 out of 398
# Matching ('tlaxcala', 'ixtacuixtla_de_mariano_matamoros'), combination 343 out of 398
# Matching ('tlaxcala', 'nativitas'), combination 344 out of 398
# Matching ('tlaxcala', 'papalotla_de_xicohtencatl'), combination 345 out of 398
# Matching ('tlaxcala', 'san_pablo_del_monte'), combination 346 out of 398
# Matching ('tlaxcala', 'santa_isabel_xiloxoxtla'), combination 347 out of 398
# Matching ('tlaxcala', 'tetla_de_la_solidaridad'), combination 348 out of 398
# Matching ('tlaxcala', 'tlaxcala'), combination 349 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'amatlan_de_los_reyes'), combination 350 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'banderilla'), combination 351 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'boca_del_rio'), combination 352 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'coatzacoalcos'), combination 353 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'cordoba'), combination 354 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'el_higo'), combination 355 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'espinal'), combination 356 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'hueyapan_de_ocampo'), combination 357 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'isla'), combination 358 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'ixtaczoquitlan'), combination 359 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'las_vigas_de_ramirez'), combination 360 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'naranjos_amatlan'), combination 361 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'orizaba'), combination 362 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'panuco'), combination 363 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'perote'), combination 364 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'poza_rica_de_hidalgo'), combination 365 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'pueblo_viejo'), combination 366 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'san_juan_evangelista'), combination 367 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'tierra_blanca'), combination 368 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'tihuatlan'), combination 369 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'tuxpan'), combination 370 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'veracruz'), combination 371 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'xalapa'), combination 372 out of 398
# Matching ('veracruz_de_ignacio_de_la_llave', 'yanga'), combination 373 out of 398
# Matching ('yucatan', 'kanasin'), combination 374 out of 398
# Matching ('yucatan', 'merida'), combination 375 out of 398
# Matching ('yucatan', 'progreso'), combination 376 out of 398
# Matching ('yucatan', 'ticul'), combination 377 out of 398
# Matching ('yucatan', 'tixkokob'), combination 378 out of 398
# Matching ('yucatan', 'uman'), combination 379 out of 398
# Matching ('zacatecas', 'calera'), combination 380 out of 398
# Matching ('zacatecas', 'chalchihuites'), combination 381 out of 398
# Matching ('zacatecas', 'fresnillo'), combination 382 out of 398
# Matching ('zacatecas', 'guadalupe'), combination 383 out of 398
# Matching ('zacatecas', 'jerez'), combination 384 out of 398
# Matching ('zacatecas', 'juan_aldama'), combination 385 out of 398
# Matching ('zacatecas', 'morelos'), combination 386 out of 398
# Matching ('zacatecas', 'ojocaliente'), combination 387 out of 398
# Matching ('zacatecas', 'rio_grande'), combination 388 out of 398
# Matching ('zacatecas', 'zacatecas'), combination 389 out of 398

# %% [markdown]
# # Concatenate and save results
# First, we concatenate all the files with the prefix `output_file_prefix`, then we label them by algorithm and DENUE's geographical selection, finally, we drop duplicate matches and save it.

# %%
joint_matches = pd.concat([pd.read_csv(f) for f in 
                           glob.glob(output_file_prefix +'*.csv')], ignore_index=True) # concatenate the results
joint_matches['algorithm'] = 'tf-idf' # label the algorithm
joint_matches['selection'] = 'both_entity_municipality_alternative' # label the database selection
joint_matches.drop_duplicates(ignore_index = True).to_csv(final_output, index = False) # drop duplicates and save
